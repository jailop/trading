# %%
from alpaca_trade_api import REST, Stream
import config

# %%
client = REST(config.API_KEY, config.API_SECRET)
news = client.get_news(
    symbol="AAPL",
    start="2020-07-01",
    end="2024-07-31",
    limit=1000
)

# %%
len(news)
# Out:
# 1000

# %%
news
# Out:
# [NewsV2({   'author': 'Anusuya Lahiri',
#      'content': '',
#      'created_at': '2024-07-30T20:21:53Z',
#      'headline': "Affirm's Growth Boosted by Apple and Amazon Partnerships, "
#                  'Lower Interest Rates: Analyst',
#      'id': 40050907,
#      'images': [   {   'size': 'large',
#                        'url': 'https://cdn.benzinga.com/files/imagecache/2048x1536xUP/images/story/2024/07/30/Affirm-Card.png'},
#                    {   'size': 'small',
#                        'url': 'https://cdn.benzinga.com/files/imagecache/1024x768xUP/images/story/2024/07/30/Affirm-Card.png'},
#                    {   'size': 'thumb',
#                        'url': 'https://cdn.benzinga.com/files/imagecache/250x187xUP/images/story/2024/07/30/Affirm-Card.png'}],
#      'source': 'benzinga',
#      'summary': 'AFRM shares rise after BofA Securities upgrades to Buy with '
#                 '$36 PT. Kupferberg expects GAAP profitability sooner, strong '
# ...
